# %%
import numpy as np
import pandas as pd
from pprint import *
import pypsa

# display options
import warnings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

# %%
df = pd.read_csv(r"C:\Users\Willem\pypsa-eur\data\bundle\time_series_60min_singleindex_filtered.csv")

# %%
n = pypsa.Network(r"C:\Users\Willem\pypsa-eur\results\networks\elec_s_6_ec_lcopt_Co2L-24H.nc")
# Out:
# C:\Users\Willem\.conda\envs\pypsa-eur\lib\site-packages\pypsa\io.py:769: FutureWarning:
#
# Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#
# C:\Users\Willem\.conda\envs\pypsa-eur\lib\site-packages\pypsa\io.py:771: FutureWarning:
#
# Index.__or__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__or__.  Use index.union(other) instead
#
# INFO:pypsa.io:Imported network elec_s_6_ec_lcopt_Co2L-24H.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units

# %%
n.plot()
display(n.loads_t)
display(n.generators)
display(n.generators_t.p)
# Out:
# {'p_set':                    DE0 0        DE0 1         DE0 2         DE0 3  \
#  name
#  2016-01-01  10573.705354  4713.619059   8660.895960   7926.385504
#  2016-01-02  11893.290976  5301.873009   9741.765287   8915.588815
#  2016-01-03  11759.495809  5242.228880   9632.173995   8815.291706
#  2016-01-04  14521.790253  6473.623486  11894.762557  10885.995391
#  2016-01-05  15024.811237  6697.863638  12306.785804  11263.075904
#  ...                  ...          ...           ...           ...
#  2016-12-27  12856.834837  5731.408215  10531.001685   9637.891908
#  2016-12-28  12912.238178  5756.106297  10576.382425   9679.424013
#  2016-12-29  12922.343653  5760.611185  10584.659794   9686.999398
#  2016-12-30  12873.960220  5739.042486  10545.029044   9650.729640
#  2016-12-31  12093.337960  5391.051328   9905.623277   9065.550390
#
#                    DE0 4         DE0 5
#  name
#  2016-01-01  5037.803081   8171.178625
#  2016-01-02  5666.514804   9190.931821
# ...
