# %%
import math
import numbers
import random

from fractions import Fraction
from decimal import Decimal
from itertools import groupby
from bisect import bisect_left, bisect_right
from math import hypot, sqrt, fabs, exp, erf, tau, log, fsum
from operator import itemgetter
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import scipy
from scipy import *
import statistics
from statistics import mean
from scipy.stats import ttest_ind
from array import array
import seaborn as sns
from scipy import stats

# %%
df_heredity= pd.read_csv(r"Z:Laura\Excel_Sheets\CSV3.csv", sep = ";", engine = "python")
display (df_heredity)           
df_heredity = df_heredity.rename(columns={'ï»¿2019': '2019'})
display (df_heredity)
# Out:
#     ï»¿2019   2020
# 0     147.0  144.6
# 1     228.2  235.3
# 2     174.5  210.6
# 3     132.9  157.3
# 4     196.5  197.8
# 5     177.3  183.3
# 6     179.7  174.5
# 7     210.3  230.9
# 8     250.0  233.8
# 9     219.0  179.8
# 10    150.8  168.3
# 11    175.0  174.5
# 12    142.6  138.8
# 13    139.5  158.0
# 14    178.3  227.3
# 15    190.7  180.8
# 16    173.0  179.8
# 17    253.8  246.7
# 18    208.5  206.4
# 19    205.2  233.7
# 20    146.9  134.3
# 21    163.8  172.8
# 22    215.0  192.3
# 23    198.3  214.7
# 24    244.7  192.1
# 25    165.3  185.8
# 26    192.3  195.0
# 27    170.9  196.6
# 28    204.2  168.4
# 29    195.3  182.8
# 30    155.5  186.3
# 31    164.4  175.1
# 32    175.5  146.0
# 33    191.3  196.5
# 34    188.2  163.0
# 35    219.5  218.0
# 36    137.3  133.0
# 37    200.8  171.3
# 38    206.0  193.8
# 39    211.2  207.4
# 40    137.3  144.2
# 41    140.0  137.2
# 42    225.3  160.5
# 43    266.5  213.0
# 44    241.8  220.0
# 45    173.8  151.3
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-a1dd62c95791> in <module>
# ----> 1 display (df_heredity, column = 'mean2020')
#
# c:\programdata\anaconda3\envs\tensorflow1\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318                 # kwarg-specified metadata gets precedence
#     319                 _merge(md_dict, metadata)
# --> 320             publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     321     if display_id:
#     322         return DisplayHandle(display_id)
#
# c:\programdata\anaconda3\envs\tensorflow1\lib\site-packages\IPython\core\display.py in publish_display_data(data, metadata, source, transient, **kwargs)
#     120         data=data,
#     121         metadata=metadata,
# --> 122         **kwargs
#     123     )
#     124
#
# ...

# %%
print(type (df_heredity))
fig, ax = plt.subplots (figsize = (10, 5), )
plt.tight_layout()

plt.subplots_adjust(left=0.25, bottom=None, right=None, top=None, wspace=0.1, hspace=0.2)
stacked=True,
patch_artist=True


props = dict(boxes="limegreen", whiskers="royalblue", medians="DarkBlue", caps="royalblue")

ax = df_heredity.plot.box(ax=ax, color=props,patch_artist=True)
ax.set(
axisbelow=True,
title='Comparison 2019 vs 2020',
xlabel= 'Year',
ylabel= 'Median'),
ax.grid(color = 'grey', linestyle = ':', linewidth = 1.0)

#ax.set_aspect(1)


#df_heredity = pd.DataFrame(df_heredity["median2020"].groupby(pd.cut(df_heredity['median2020'], bins= 2)).count())
#df_heredity = pd.DataFrame(df_heredity["median2019"].groupby(pd.cut(df_heredity['median2019'], bins= 2)).count())

#df_heredity[['Year'] == '2019-2020'].boxplot(column='Mean 2020')

#boxplot = df_heredity.boxplot(column=['median2019', 'median2020'])

title_boxplot = "Comparison Median 2019 vs 2020"
plt.title (title_boxplot)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_heredity.plot(style=['o','gx'])
figsize = (10, 5)
plt.title('Comparison Median 2019 vs.2020', size=14)
#plt.xlabel('year', size=12)
plt.legend(labels=['2019', '2020'])
plt.xaxis=False
plt.ylabel('Stomatal count', size=12);

# create linear regression object
lr_heredity_2019 = LinearRegression()

index = df_heredity.index.values.reshape(len(df_heredity.index.values),1)


# fit linear regression
lr_heredity_2019.fit(index, df_heredity['2019'])

# get the slope and intercept of the line best fit
b = lr_heredity_2019.intercept_
print (b)
# -224.49884070545772

m= lr_heredity_2019.coef_
print (m)
# 5.96177381
plt.plot(index,m*index+b, color = 'green')

#df_comparison = df_comparison[df_comparison['Manually counted']

# create linear regression object
lr_heredity_2020 = LinearRegression()

# fit linear regression
lr_heredity_2020.fit(index, df_heredity['2020'])

# get the slope and intercept of the line best fit
b = lr_heredity_2020.intercept_
print(b)
# -246.01326574667277
m = lr_heredity_2020.coef_
print(m)

plt.plot(index,m*index+b, color = 'blue')

matplotlib.pyplot.show()
# Out:
# 182.588081632653
# [0.21180612]
# 193.57004081632653
# [-0.36873469]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-4d35bd85b51d> in <module>
#      43 plt.plot(index,m*index+b, color = 'blue')
#      44
# ---> 45 matplotlib.pyplot.show()
#
# NameError: name 'matplotlib' is not defined

# %%
ax1= df_heredity.plot(x='2019', y='2020', style=['o','gx'])
figsize = (10, 5)
plt.title('Comparison Median 2019 vs.2020', size=14)
plt.legend(labels=['2019', '2020'])
plt.xaxis='2019'
plt.ylabel('2020', size=12);
plt.show()

df_heredity.plot(style=['o','gx'])
figsize = (10, 5)
plt.title('Comparison Median 2019 vs.2020', size=14)
#plt.xlabel('year', size=12)
plt.legend(labels=['2019', '2020'])
plt.xaxis='2019'
plt.ylabel('2020', size=12);

plt.show()

# create linear regression object
lr_heredity_2019 = LinearRegression()

index = df_heredity.index.values.reshape(len(df_heredity.index.values),1)


# fit linear regression
lr_heredity_2019.fit(df_heredity['2020'], df_heredity['2019'])

# get the slope and intercept of the line best fit
b = lr_heredity_2019.intercept_
print (b)
# -224.49884070545772

m= lr_heredity_2019.coef_
print (m)
# 5.96177381
plt.plot(index,m*index+b, color = 'green')

#df_comparison = df_comparison[df_comparison['Manually counted']

# create linear regression object
lr_heredity_2020 = LinearRegression()

# fit linear regression
lr_heredity_2020.fit(df_heredity['2019'], df_heredity['2020'])

# get the slope and intercept of the line best fit
b = lr_heredity_2020.intercept_
print(b)
# -246.01326574667277
m = lr_heredity_2020.coef_
print(m)

plt.plot(index,m*index+b, color = 'blue')

matplotlib.pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-cfc737dd3bf5> in <module>
#      24
#      25 # fit linear regression
# ---> 26 lr_heredity_2019.fit(df_heredity['2020'], df_heredity['2019'])
#      27
#      28 # get the slope and intercept of the line best fit
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# ...

# %%
ax1= df_heredity[df_heredity['2019']].plot(kind ='scatter',x='index', y='2019', color= 'red',alpha=0.5,figsize=(10,5)),
df_heredity[df_heredity['2020']].plot(kind='scatter',x='index',y='2020',color='green', alpha= 0.5, figsize=(10,5),ax=ax1),

plt.title('Comparison Median 2019 vs 2020 Row 23', size=14),
plt.legend(labels=['Row 23 2019', 'Row 23 2020']),
plt.xaxis('Sample number'),
plt.ylabel('Stomatal count (Median)', size=12),
            
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-6ee0a3419576> in <module>
# ----> 1 ax1= df_heredity[df_heredity['2019']].plot(kind ='scatter',x='index', y='2019', color= 'red',alpha=0.5,figsize=(10,5)),
#       2 df_heredity[df_heredity['2020']].plot(kind='scatter',x='index',y='2020',color='green', alpha= 0.5, figsize=(10,5),ax=ax1),
#       3
#       4 plt.title('Comparison Median 2019 vs 2020 Row 23', size=14),
#       5 plt.legend(labels=['Row 23 2019', 'Row 23 2020']),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ...

# %%
ax1= df_heredity.plot(kind ='scatter',x='2019', y='2020', color= 'blue')
#df_heredity.plot(kind='scatter',x='2019',y='2020',color='green', alpha=0.5, figsize=(10,5),ax=ax1)
fig=plt.figure()
#ax1 =fig.add_subplot(48,2,2)
# create linear regression object
lr_heredity = LinearRegression()

index = df_heredity.index.values.reshape(len(df_heredity.index.values),1)


# fit linear regression
lr_heredity.fit(index, df_heredity)

# get the slope and intercept of the line best fit
b = lr_heredity.intercept
print (b)
# -224.49884070545772

m= lr_heredity.coef
print (m)
# 5.96177381
plt.plot(index,m*index+b, color = 'green')
#df_heredity.plt.scatter(x='2019', y='2020',c='b', marker ='x',label='2019')
#df_heredity.plt.scatter(x='2019',y='2020',c='g', marker='o', label ='2020')
#plt.legend(loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-7fb2747733cc> in <module>
#      13
#      14 # get the slope and intercept of the line best fit
# ---> 15 b = lr_heredity.intercept
#      16 print (b)
#      17 # -224.49884070545772
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept'

# %%
ax1= df_heredity.plot(kind ='scatter',x='2019', y='2020', color= 'blue')
fig=plt.figure()

ax = sns.regplot(x="2019", y= "2020",data=df_heredity)
#lr_heredity = LinearRegression()
#index = df_heredity.index.values.reshape(len(df_heredity.index.values),1)
#lr_heredity.fit(index, df_heredity)
#x = ["2019"]
#b = lr_heredity.intercept_
#m= lr_heredity.coef_
#plt.plot(x, b +m *x, color = 'green')

#def r2 (x="2019",y="2020"):
   # return stats.pearsonr(x="2019",y="2020")[0]**2
#sns.jointplot(x="2019",y="2020", kind="reg", stat_func=r2)
res=stats.linregress(x=df_heredity["2019"],y=df_heredity["2020"])
print(f"R-squared:{res.rvalue**2:.6f}")
#plt (f"R-squared:{res.rvalue**2:.6f}")
print(f"p-value:{res.pvalue**2:.6f}")
#slope, intercept, r, p, se = linregress("2019", "2020")
#result = linregress("2019", "2020")
#print(result.intercept, result.intercept_stderr)

plt.show()
# Out:
# R-squared:0.549465
# p-value:0.000000

# %%
data_2019 = df_heredity["2019"]
data_2020 = df_heredity["2020"]
scipy.stats.ttest_ind(data_2019,data_2020)
# Out:
# Ttest_indResult(statistic=0.455235758242459, pvalue=0.6499675533575018)

# %%
df_heredity.plot(style=['o','gx'])

figsize = (10, 5)
plt.legend(labels=['Row 23 2019', 'Row 23 2020'])
plt.title('Comparison Median 2019 vs.2020 Row 23', size=14)
# Out:
# Text(0.5, 1.0, 'Comparison Median 2019 vs.2020 Row 23')

# %%
ax= df_heredity.plot.bar(x='Genotype', y= ["2019","2020"], color=['blue','green'] )

plt.title ('Comparison Median 2019 vs. 2020 Row 24')
plt.ylabel('Stomatal count (Median)')
# Out:
# Text(0, 0.5, 'Stomatal count (Median)')

# %%
ax= df_heredity.plot.bar(x='Genotype', y= ["2019","2020"], color=['blue','green'] )

plt.title ('Comparison Median 2019 vs. 2020 Row 23')
plt.ylabel('Stomatal count (Median)')
# Out:
# Text(0, 0.5, 'Stomatal count (Median)')

# %%
# calculate means
mean1, mean2 = mean(df_heredity["2019"]), mean(df_heredity["2020"])

# calculate sample standard deviations
std1, std2 = np.std(df_heredity["2019"], ddof=1), np.std(df_heredity["2020"], ddof=1)

# calculate standard errors
n1, n2 = len(df_heredity["2019"]), len(df_heredity["2020"])
se1, se2 = std1/sqrt(n1), std2/sqrt(n2)

# calculate standard errors
se1, se2 = sem("2019"), sem("2020")

# standard error on the difference between the samples
sed = sqrt(se1**2.0 + se2**2.0)

# calculate the t statistic
t_stat = (mean1 - mean2) / sed

# degrees of freedom
df = n1 + n2 - 2

# calculate the critical value
alpha = 0.05
cv = t.ppf(1.0 - alpha, df)

# calculate the p-value
p = (1.0 - t.cdf(abs(t_stat), df)) * 2.0
# return everything
return t_stat, df, cv, p
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-192-3e2c4724a487> in <module>
#      10
#      11 # calculate standard errors
# ---> 12 se1, se2 = sem("2019"), sem("2020")
#      13
#      14 # standard error on the difference between the samples
#
# NameError: name 'sem' is not defined

# %%
df_heredity["2019"]= array[df_heredity["2019"]]
df_heredity["2020"]= array[df_heredity["2020"]]

tStat,twoTailProb =ttest_ind[df_heredity["2019"],df_heredity["2020"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-188-917c5a8bec94> in <module>
# ----> 1 df_heredity["2019"]= array[df_heredity["2019"]]
#       2 df_heredity["2020"]= array[df_heredity["2020"]]
#       3
#       4 tStat,twoTailProb =ttest_ind[df_heredity["2019"],df_heredity["2020"]]
#
# TypeError: 'type' object is not subscriptable

# %%
scipy.stats.ttest_rel(a= df_heredity["2019"], b=df_heredity["2020"]
# Out:
#   File "<ipython-input-203-7fb7a4366907>", line 1
#     scipy.stats.ttest_rel(a= df_heredity["2019"], b=df_heredity["2020"]
#                                                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
data_2019 = df_heredity["2019"]
data_2020 = df_heredity["2020"]
ttest_ind(data_2019,data_2020)
# Out:
# Ttest_indResult(statistic=0.455235758242459, pvalue=0.6499675533575018)

# %%
a=df_heredity["2019"]
b=df_heredity["2020"]
scipy.stats.mstats.ttest_rel(a,b, axis=0)
# Out:
# Ttest_relResult(statistic=0.8866760584572029, pvalue=0.37967440320717305)

# %%
df_heredity_statistic= pd.read_csv(r"Z:Laura\Excel_Sheets\CSV3 for statistic.csv", sep = ";", engine = "python")
display (df_heredity_statistic)           
df_heredity_statistic = df_heredity_statistic.rename(columns={'ï»¿Sample': 'Sample'})
display (df_heredity_statistic)
# Out:
#     ï»¿Sample   2019   2020  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 0           1  147.0  144.6         NaN         NaN         NaN         NaN
# 1           2  228.2  235.3         NaN         NaN         NaN         NaN
# 2           3  174.5  210.6         NaN         NaN         NaN         NaN
# 3           4  132.9  157.3         NaN         NaN         NaN         NaN
# 4           5  196.5  197.8         NaN         NaN         NaN         NaN
# 5           6  177.3  183.3         NaN         NaN         NaN         NaN
# 6           7  179.7  174.5         NaN         NaN         NaN         NaN
# 7           8  210.3  230.9         NaN         NaN         NaN         NaN
# 8           9  250.0  233.8         NaN         NaN         NaN         NaN
# 9          10  219.0  179.8         NaN         NaN         NaN         NaN
# 10         11  150.8  168.3         NaN         NaN         NaN         NaN
# ...

# %%
n=index
a=df_heredity["2019"].iloc[index]
b=df_heredity["2020"].iloc[index]
scipy.stats.mstats.ttest_1samp(a,b, axis=n)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-9da9e3691348> in <module>
#       1 n=index
# ----> 2 a=df_heredity["2019"].iloc[index]
#       3 b=df_heredity["2020"].iloc[index]
#       4 scipy.stats.mstats.ttest_1samp(a,b, axis=n)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1485         # a list of integers
#    1486         elif is_list_like_indexer(key):
# -> 1487             return self._get_list_axis(key, axis=axis)
#    1488
#    1489         # a single integer
#
# ...

# %%
a=df_heredity["2019"]
b=df_heredity["2020"]
scipy.stats.mstats.ttest_rel(a,b, axis=0)
# Out:
# Ttest_relResult(statistic=0.8866760584572029, pvalue=0.37967440320717305)

# %%
a=df_heredity.loc[0, "2019"]
b=df_heredity.loc[0,"2019"]
scipy.stats.mstats.ttest_rel(a,b, axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-e3277f40a61a> in <module>
#       1 a=df_heredity.loc[0, "2019"]
#       2 b=df_heredity.loc[0,"2019"]
# ----> 3 scipy.stats.mstats.ttest_rel(a,b, axis=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\mstats_basic.py in ttest_rel(a, b, axis)
#    1115     """
#    1116     a, b, axis = _chk2_asarray(a, b, axis)
# -> 1117     if len(a) != len(b):
#    1118         raise ValueError('unequal length arrays')
#    1119
#
# TypeError: len() of unsized object
